# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
x = np.array([0,6])
y = np.array([0,250])

plt.plot(x,y)
plt.show()

# %%
x = np.array([1,8])
y = np.array([3,10])

plt.plot(x,y,"o")
plt.show()

# %%
x = np.array([1,2,6,8])
y = np.array([3,8,1,10])

plt.plot(x,y)
plt.show()

# %%
y = np.array([3,8,1,10,5,7])

plt.plot(y)
plt.show()

# %%
x = np.array([0,1,2,3,4,5])
plt.plot(x)
plt.show()

# %%
x = np.array([2,6,3,6,4])

plt.plot(x)
plt.show()

# %%
y = np.array([3,8,1,10])

plt.plot(y,marker = "o")
plt.show()

# %%
x = np.array([3,8,1,10])

plt.plot(x,marker ="*")
plt.show()

# %%
x = np.array([1,5,3,7])

plt.plot(x,"*")
plt.show()

# %%
y = np.array([3,8,1,10])

plt.plot(y,"o:r")
plt.show()

# %%
y = np.array([3,8,1,10])

plt.plot(y,"or")
plt.show()

# %%
y = np.array([3,8,1,10])

plt.plot(y,marker ="o",ms=20)
plt.show()

# %%
y = np.array([3,8,1,10])

plt.plot(y,marker = "o", ms = 20, mec ="r")
plt.show()

# %%
y = np.array([3,8,1,10])

plt.plot(y, marker = "o" , ms = 20, mfc = "r")
plt.show()

# %%
y = np.array([3,8,1,10])

plt.plot(y,marker ="o",ms = 20,mec="#4CAF50",mfc="#4CAF50")
plt.show()

# %%
y = np.array([3,8,1,10])

plt.plot(y,marker="o",ms=20,mec="hotpink",mfc="hotpink")
plt.show()

# %%
y = np.array([3,8,1,10])
plt.plot(y,linestyle = "dotted")
plt.show()

# %%
y = np.array([3,8,1,10])

plt.plot(y,ls = "dashed")
plt.show()

# %%
 y = np.array([3,8,1,10])

plt.plot(y,color="r")
plt.show()

# %%
y = np.array([3,8,1,10])

plt.plot(y,linewidth = "20.5")
plt.show()

# %%
y1 = np.array([3,8,1,10])
y2 = np.array([6,2,7,11])

plt.plot(y1,"r")
plt.plot(y2,"g")
plt.show()

# %%
x1 = np.array([3,8,1,10])
y1 = np.array([3,2,5,8])

x2 = np.array([3,6,5,10])
y2 = np.array([5,8,2,10])

plt.plot(x1,y1,marker = "o" , ms = 20,mec = "hotpink" ,mfc = "hotpink")
plt.plot(x2,y2)

plt.show()
plt.show()

# %%
x = np.array([80,85,90,95])
y = np.array([240,250,260,270])
plt.plot(x,y)

plt.xlabel("Average pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
x = np.array([80,85,90,95])
y = np.array([240,250,260,270])

plt.plot(x,y)
plt.xlabel("Average Pulse")
plt.ylabel("Colrie Burnage")
plt.title("Sports Watch Data")

plt.show()

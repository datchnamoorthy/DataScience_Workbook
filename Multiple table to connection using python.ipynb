# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+mysqlconnector://root:012345@127.0.0.1/PATIENTS_PACEMAKER_MANAGEMENT_SYSTEM")

# %%
query = "SELECT * FROM IMP"

# %%
df = pd.read_sql(query, engine)
df
# Out:
#    PATIENT_ID                NAME DATE_OF_BIRTH  GENDER PHONE_NUMBER  \
# 0      PID001     Arjun Rajendran    1985-07-15    Male   9876543210
# 1      PID002  Meenakshi Sundaram    1990-11-22  Female   8765432190
# 2      PID003  Karthikeyan Pillai    1978-03-08    Male   7654321890
# 3      PID004        Deepika Iyer    1982-09-30  Female   6543219870
# 4      PID005       Senthil Kumar    1995-04-17    Male   9432108765
# ..        ...                 ...           ...     ...          ...
# 95     PID096  Lakshmi Narasimhan    1988-10-30  Female   9876543211
# 96     PID097          Srinivas K    1979-11-05    Male   6765432191
# 97     PID098      Priyanka Menon    1994-12-10  Female   7654321981
# 98     PID099         Ajith Kumar    1986-01-15    Male   9543219871
# 99     PID100          Nandhini R    1990-02-20  Female   9432108766
#
#                        EMAIL_ID                         ADDRESS PACEMAKER_ID  \
# ...

# %%
df.to_excel(r"C:\Users\Datchnamoorthy R\Downloads\pacemaker dataset.xlsx", index=False)
df
# Out:
#    PATIENT_ID                NAME DATE_OF_BIRTH  GENDER PHONE_NUMBER  \
# 0      PID001     Arjun Rajendran    1985-07-15    Male   9876543210
# 1      PID002  Meenakshi Sundaram    1990-11-22  Female   8765432190
# 2      PID003  Karthikeyan Pillai    1978-03-08    Male   7654321890
# 3      PID004        Deepika Iyer    1982-09-30  Female   6543219870
# 4      PID005       Senthil Kumar    1995-04-17    Male   9432108765
# ..        ...                 ...           ...     ...          ...
# 95     PID096  Lakshmi Narasimhan    1988-10-30  Female   9876543211
# 96     PID097          Srinivas K    1979-11-05    Male   6765432191
# 97     PID098      Priyanka Menon    1994-12-10  Female   7654321981
# 98     PID099         Ajith Kumar    1986-01-15    Male   9543219871
# 99     PID100          Nandhini R    1990-02-20  Female   9432108766
#
#                        EMAIL_ID                         ADDRESS PACEMAKER_ID  \
# ...

# %%
# Note : 
'''Importing multiple table in python and modelling is difficult so , we need to use join concepts to join multiple table into single table 
with necessary columns and store it in view. 
Then we need call it in python code 
(i.e) SELECT * FROM VIEW_NAME'''
